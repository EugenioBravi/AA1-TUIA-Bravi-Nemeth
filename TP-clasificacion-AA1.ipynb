# %% [markdown]
# # Trabajo practico Nº2 AA1
# 25/10/24
#
# Integrantes:
#
# Bravi Eugenio B-6600/1
#
# Nemeth Ulises N-1249/1

# %% [markdown]
# ## Introducción
# En este trabajo nos enfocamos en la predicción del clima en 10 ciudades de Australia, específicamente en predecir si va a llover o no al día siguiente.
#
# Nos enfrentamos a algunos problemas, como valores faltantes, datos desbalanceados (con más días sin lluvia que con lluvia) y variables que varían mucho de un lugar a otro. Para lograr el objetivo, probamos diferentes estrategias y comparamos modelos.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import math
from sklearn.preprocessing import RobustScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.metrics import  roc_curve, auc, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, make_scorer, cohen_kappa_score
from imblearn.over_sampling import RandomOverSampler
from sklearn.dummy import DummyClassifier
import shap
from sklearn.model_selection import cross_val_score, StratifiedKFold
import optuna
from pycaret.classification import *

# %% [markdown]
# # Analisis Exploratorio

# %% [markdown]
# ## Dataset wheatherAUS
# Explicación de las columnas:
#
# **Date**: Fecha del registro.
#
# **Location**: Nombre de la ciudad.
#
# **MinTemp**: Temperatura minima del día.
#
# **MaxTemp**: Temperatura Maxima del día.
#
# **Rainfall**: Cantidad de milimetros que llovio ese día.
#
# **Evaporation**: Cantidad de evaporacion en milimetros que hubo ese día.
#
# **Sunshine**: Cantidad de horas del sol en el día.
#
# **WindGustDir**: Dirección de la rafaga de viento más fuerte.
#
# **WindGustSpeed**: Velocidad en km/h de la rafaga de viento más fuerte.
#
# **WindDir9am - WindDir3pm**: Direccion del viento en determinado horario.
#
# **WindSpeed9am - WindSpeed3pm**: Velocidad del viento en determinado horario.
#
# **Humidity9am - Humidity3pm**: Cantidad de humedad en determinado horario.
#
# **Pressure9am - Pressure3pm**: Cantidad de presión atmosferica en determinado horario.
#
# **Cloud9am - Cloud3pm**: Covertura de las nubes en determinado horario.
#
# **Temp9am - Temp3pm**: Temperatura en determinado horario.
#
# **RainToday**: Indica si hubo lluvias en ese día.
#
# **RainTomorrow**: Indica si hubo lluvias en el dia siguiente.

# %%
df = pd.read_csv('./weatherAUS.csv')
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8         No
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3         No
# 2       1007.6       1008.7       NaN       2.0     21.0     23.2         No
# 3       1017.6       1012.8       NaN       NaN     18.1     26.5         No
# 4       1010.8       1006.0       7.0       8.0     17.8     29.7         No
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
#
# [5 rows x 23 columns]

# %%
#Buscamos 10 ciudades al azar
ciudades = pd.Series(df['Location'].unique()).sample(n=10,random_state=23)
ciudades
# Out:
# 14     Wollongong
# 18       Ballarat
# 17    MountGinini
# 43         Hobart
# 13    Williamtown
# 32       Adelaide
# 20           Sale
# 8         Penrith
# 35        Woomera
# 41     SalmonGums
# dtype: object

# %%
# Nos quedamos con las ciudades elegidas
df_ciudades = df[df['Location'].isin(ciudades)]

# %%
df_ciudades.describe()
# Out:
#             MinTemp       MaxTemp      Rainfall   Evaporation      Sunshine  \
# count  30388.000000  30432.000000  29659.000000  11240.000000  10128.000000
# mean      10.433645     21.197062      2.028969      6.016957      7.368385
# std        5.992917      7.587854      7.169184      6.285084      3.749717
# min       -8.500000     -4.800000      0.000000      0.000000      0.000000
# 25%        6.200000     16.300000      0.000000      2.400000      4.600000
# 50%       10.300000     20.600000      0.000000      4.400000      8.000000
# 75%       14.700000     25.700000      0.600000      7.400000     10.300000
# max       33.900000     48.100000    225.000000    145.000000     14.200000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm   Humidity9am   Humidity3pm  \
# count   29662.000000  30169.000000  30206.000000  29900.000000  30053.000000
# mean       42.056604     15.202625     18.972721     69.255084     51.862376
# std        15.082270      9.091524      9.342793     20.287892     21.959883
# min         7.000000      0.000000      0.000000      0.000000      0.000000
# 25%        31.000000      9.000000     13.000000     56.000000     36.000000
# 50%        41.000000     15.000000     19.000000     71.000000     51.000000
# 75%        50.000000     20.000000     24.000000     85.000000     67.000000
# max       135.000000     87.000000     72.000000    100.000000    100.000000
#
#         Pressure9am   Pressure3pm      Cloud9am      Cloud3pm       Temp9am  \
# count  21373.000000  21400.000000  13562.000000  12761.000000  30024.000000
# mean    1017.718930   1015.681547      4.776139      4.824857     15.047828
# std        7.864169      7.703095      2.921765      2.799680      6.239875
# min      982.200000    977.100000      0.000000      0.000000     -7.200000
# 25%     1012.800000   1010.800000      2.000000      2.000000     10.900000
# 50%     1018.000000   1016.000000      6.000000      6.000000     14.900000
# 75%     1023.100000   1020.900000      7.000000      7.000000     19.300000
# max     1040.400000   1038.900000      8.000000      9.000000     38.600000
#
#             Temp3pm
# count  30175.000000
# mean      19.782830
# std        7.413504
# min       -5.400000
# 25%       15.100000
# 50%       19.200000
# 75%       24.200000
# max       46.200000

# %%
df_ciudades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30573 entries, 24128 to 133030
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           30573 non-null  object
#  1   Location       30573 non-null  object
#  2   MinTemp        30388 non-null  float64
#  3   MaxTemp        30432 non-null  float64
#  4   Rainfall       29659 non-null  float64
#  5   Evaporation    11240 non-null  float64
#  6   Sunshine       10128 non-null  float64
#  7   WindGustDir    29661 non-null  object
#  8   WindGustSpeed  29662 non-null  float64
#  9   WindDir9am     28936 non-null  object
#  10  WindDir3pm     30043 non-null  object
#  11  WindSpeed9am   30169 non-null  float64
#  12  WindSpeed3pm   30206 non-null  float64
#  13  Humidity9am    29900 non-null  float64
#  14  Humidity3pm    30053 non-null  float64
#  15  Pressure9am    21373 non-null  float64
#  16  Pressure3pm    21400 non-null  float64
#  17  Cloud9am       13562 non-null  float64
#  18  Cloud3pm       12761 non-null  float64
#  19  Temp9am        30024 non-null  float64
#  20  Temp3pm        30175 non-null  float64
#  21  RainToday      29659 non-null  object
#  22  RainTomorrow   29658 non-null  object
# dtypes: float64(16), object(7)
# memory usage: 5.6+ MB

# %%
df_ciudades.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp            185
# MaxTemp            141
# Rainfall           914
# Evaporation      19333
# Sunshine         20445
# WindGustDir        912
# WindGustSpeed      911
# WindDir9am        1637
# WindDir3pm         530
# WindSpeed9am       404
# WindSpeed3pm       367
# Humidity9am        673
# Humidity3pm        520
# Pressure9am       9200
# Pressure3pm       9173
# Cloud9am         17011
# Cloud3pm         17812
# Temp9am            549
# Temp3pm            398
# RainToday          914
# RainTomorrow       915
# dtype: int64

# %%
#Eliminamos las filas que tienen null en el valor a predecir.
df_ciudades = df_ciudades.dropna(subset=['RainTomorrow'])

# %%
df_ciudades = df_ciudades.dropna(subset=['RainToday'])

# %% [markdown]
# Se dicide eliminar las filas que no tienen valores en 'RainToday' ya que al imputar los datos faltantes se 'ensucia' el dataset y se obtiene peores resultados en los modelos

# %%
location_counts = df_ciudades['Location'].value_counts()
print("Cantidad de datos por ciudad:")
print(location_counts)
# Out:
# Cantidad de datos por ciudad:
# Location
# Hobart         3183
# Adelaide       3020
# Ballarat       3017
# Sale           2992
# Woomera        2984
# Wollongong     2943
# SalmonGums     2941
# Penrith        2911
# MountGinini    2816
# Williamtown    2376
# Name: count, dtype: int64

# %% [markdown]
# Observamos que la varianza en la cantidad de datos en las distintas ciudades es menor al 10% execepto en la ciudad de Williamtown donde hay una menor cantidad de datos con respecto a las demas ciudades.

# %%
#Convertimos el tipo de dato de Date a fecha para poder obtener el mes
df_ciudades['Date'] = pd.to_datetime(df_ciudades['Date'])
df_ciudades['Month'] = df_ciudades['Date'].dt.month

#Dropeamos la columna date ya que no la vamos a necesitar
df_ciudades.drop('Date', axis=1, inplace=True)

# %% [markdown]
# ## Graficos y tratamiento de valores faltantes

# %%
#Dividimos el dataset en set de entreamiento y testeo
X_train, X_test, y_train, y_test = train_test_split(df_ciudades.drop('RainTomorrow', axis=1),
                                             df_ciudades['RainTomorrow'],
                                             test_size=0.2,
                                             random_state=24,
                                             shuffle=True
                                             )

# %%
variables_cuantitativas = X_train.select_dtypes(include=['float64']).columns
variables_cualitativas = ['WindGustDir','WindDir9am','WindDir3pm','RainToday']
# Definimos la cantidad de filas y columnas para los subplots
n_rows_cuant = math.ceil(len(variables_cuantitativas) / 2)  # Número de filas para cuantitativas
n_rows_cual = math.ceil(len(variables_cualitativas) / 2)    # Número de filas para cualitativas

# Gráficos para variables cuantitativas
fig, axes = plt.subplots(n_rows_cuant, 2, figsize=(14, 5 * n_rows_cuant))
fig.suptitle('Distribución de Variables Cuantitativas por Ciudad', fontsize=16)
axes = axes.flatten()  # Aplanamos para indexar los ejes fácilmente

for i, var in enumerate(variables_cuantitativas):
    sns.histplot(data=X_train, x=var, hue='Location', element="step", kde=True, stat="density", ax=axes[i])
    axes[i].set_title(f'Distribución de {var} por Ciudad')

# Ocultamos gráficos vacíos en caso de que sean impares
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout(rect=[0, 0, 1, 0.97])  # Ajuste del espaciado
plt.show()


# Gráficos para variables cualitativas
fig, axes = plt.subplots(n_rows_cual, 2, figsize=(14, 5 * n_rows_cual))
fig.suptitle('Distribución de Variables Cualitativas', fontsize=16)
axes = axes.flatten()  # Aplanamos para indexar los ejes fácilmente

for i, var in enumerate(variables_cualitativas):
    sns.countplot(data=X_train, x=var, ax=axes[i])
    axes[i].set_title(f'Distribución de {var}')

# Ocultamos gráficos vacíos en caso de que sean impares
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout(rect=[0, 0, 1, 0.97])  # Ajuste del espaciado
plt.show()

# %% [markdown]
# Se observa que hay distintas densidades en los datos entre las ciudades.
#
# Se observa que hay ciudades que no cuentan con valores para algunas variables.

# %% [markdown]
# ## Tratamiento de valores faltantes

# %%
group_ciudades_mes = X_train[variables_cuantitativas].groupby([X_train['Location'], X_train['Month']]).median()

for location, month in group_ciudades_mes.index:
    # Obtenemos las medianas para esta combinación de Location y Month
    medianas = group_ciudades_mes.loc[(location, month)]

    mask = (X_train['Location'] == location) & (X_train['Month'] == month)
    mask_test = (X_test['Location'] == location) & (X_test['Month'] == month)
    X_train.loc[mask, variables_cuantitativas] = X_train.loc[mask, variables_cuantitativas].fillna(medianas)
    X_test.loc[mask_test, variables_cuantitativas] = X_test.loc[mask_test, variables_cuantitativas].fillna(medianas)

# %%
group_mes = X_train[variables_cuantitativas].groupby(X_train['Month']).median()

for month in group_mes.index:
    # Obtenemos las medianas para Month
    medianas = group_mes.loc[(month)]

    mask = (X_train['Month'] == month)
    mask_test = (X_test['Month'] == month)
    X_train.loc[mask, variables_cuantitativas] = X_train.loc[mask, variables_cuantitativas].fillna(medianas)
    X_test.loc[mask_test, variables_cuantitativas] = X_test.loc[mask_test, variables_cuantitativas].fillna(medianas)

# %%
group_ciudades_mes = X_train[variables_cualitativas].groupby([X_train['Location'], X_train['Month']]).apply(lambda x: x.mode().iloc[0])
for location, month in group_ciudades_mes.index:
    # Obtenemos las medianas para esta combinación de Location y Month
    modas = group_ciudades_mes.loc[(location, month)]

    mask = (X_train['Location'] == location) & (X_train['Month'] == month)
    mask_test = (X_test['Location'] == location) & (X_test['Month'] == month)
    X_train.loc[mask, variables_cualitativas] = X_train.loc[mask, variables_cualitativas].fillna(modas)
    X_test.loc[mask_test, variables_cualitativas] = X_test.loc[mask_test, variables_cualitativas].fillna(modas)

# %%
print(X_train.isnull().sum().sum())
print(X_test.isnull().sum().sum())
# Out:
# 0
# 0

# %%
n_cols = 3  # 3 gráficos por fila
n_rows = math.ceil(len(variables_cuantitativas) / n_cols)  # Calculamos el número de filas

# Creamos los subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(12, 3 * n_rows))
fig.suptitle('Boxplot de Variables Cuantitativas', fontsize=16)
axes = axes.flatten()  # Aplanamos para indexar fácilmente los subplots

# Generamos un boxplot para cada variable cuantitativa
for i, var in enumerate(variables_cuantitativas):
    sns.boxplot(data=X_train, y=var, ax=axes[i])
    axes[i].set_title(f'Boxplot de {var}')

# Eliminamos los subplots vacíos si el número de variables no es múltiplo de 3
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# Ajuste del espaciado
plt.tight_layout(rect=[0, 0, 1, 0.97])
plt.show()

# %% [markdown]
# No utilizamos KNN Inputer debido a la alta demanda computacional debido a la gran cantidad de datos y columnas que tiene este dataset.
#
# Completamos los valores faltantes de las variables cuantitativas con la mediana de cada ciudad en cada mes. En algunas variables algunas ciudades no contaban con ningun dato en ese caso completamos con la mediana del mes de todas la ciudades.
#
# A las variables cualitativas las completamos con la moda de cada ciudad en cada mes.
#
# Tambien decidimos quedarnos con todos los valores outliers ya que creemos que son casos realistas y que pueden suceder por lo que hay que preservarlos para que el modelo sea mas robusto y preciso.

# %% [markdown]
# ## Codificación de variables categoricas

# %%
# Pasamos RainToday a boolean
X_train['RainToday'] = X_train['RainToday'].map({'Yes': 1, 'No': 0})
X_test['RainToday'] = X_test['RainToday'].map({'Yes': 1, 'No': 0})
y_train = y_train.map({'Yes': 1, 'No': 0})
y_test = y_test.map({'Yes': 1, 'No': 0})

# %%
# Location a Latitud (float64) y Longitud (float64)
location_coordenadas = {
    'Wollongong': [-34.43305,150.88305 ],
    'Ballarat': [-37.56622, 143.84957],
    'MountGinini': [-35.28346, 149.12807],
    'Hobart': [-42.88333,147.31666 ],
    'Williamtown': [-32.80899, 151.83899],
    'Adelaide': [-34.92866, 138.59863],
    'Sale': [-33.86785, 151.20732],
    'Penrith': [-33.75111, 150.69416],
    'Woomera': [-31.16563, 136.81926],
    'SalmonGums': [-32.98207, 121.64416]
}

# Creamos nuevas columnas 'Latitud' y 'Longitud' mapeando con location_coordenadas
X_train['Latitud'] = X_train['Location'].map(lambda loc: location_coordenadas[loc][0])
X_train['Longitud'] = X_train['Location'].map(lambda loc: location_coordenadas[loc][1])
X_test['Latitud'] = X_test['Location'].map(lambda loc: location_coordenadas[loc][0])
X_test['Longitud'] = X_test['Location'].map(lambda loc: location_coordenadas[loc][1])

# Eliminamos la columna 'Location'
X_train = X_train.drop(columns=['Location'])
X_test = X_test.drop(columns=['Location'])

# %%
# Las direcciones del viento a angulos (float64)
angulos = {
    'N': 0,
    'NNE': 22.5,
    'NE': 45,
    'ENE': 67.5,
    'E': 90,
    'ESE': 112.5,
    'SE': 135,
    'SSE': 157.5,
    'S': 180,
    'SSW': 202.5,
    'SW': 225,
    'WSW': 247.5,
    'W': 270,
    'WNW': 292.5,
    'NW': 315,
    'NNW': 337.5
}
for column in ['WindGustDir','WindDir9am','WindDir3pm']:
    X_train[column] = X_train[column].map(angulos)
    X_test[column] = X_test[column].map(angulos)

# %% [markdown]
# ## Correlación

# %%
# Creamos heatmap con la matriz de correlacion
correlation_matrix = X_train.corr()

# Creamos una máscara para ocultar solo la mitad superior (incluyendo los elementos estrictamente encima de la diagonal)
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))

# Graficamos la matriz de correlación
plt.figure(figsize=(16, 12))
sns.heatmap(correlation_matrix, mask=mask, annot=True, fmt=".2f", cmap="coolwarm",
            linewidths=0.5, cbar_kws={"shrink": 0.8}, square=True)
plt.title("Correlation Matrix (Lower Triangle with Diagonal)")
plt.show()

# %% [markdown]
# Se observa que las variables que tienen mediciones en distintos horarios tienden a tener una alta correlación entre ellas. por ejemplo la temperatura a las 3pm tiene una correlacion de 0.98 con la temperatura maxima del dia.
#
# Tambien se observa que la temperatura y la humedad estan medianamente correlacionadas negativamente.
#
# La evaporacion y las horas de sol estan medianamente correlacionadas con la temperatura.

# %% [markdown]
# ## Balance del modelo

# %%
# Visualizamos el balance
sns.countplot(x='RainTomorrow', data=y_train.to_frame())
plt.title('Distribución de RainTomorrow')
plt.show()
print(round(y_train.value_counts() / len(y_train) *100,0))
# Out:
# RainTomorrow
# 0    79.0
# 1    21.0
# Name: count, dtype: float64

# %% [markdown]
# El dataset no esta balanceado debido a que casi el 80% de los datos son de NO lluvia. Esto prodria significar en que el modelo vaya a aprender a predecir la clase mayoritaria, para evitar eso se tendria que aplicar tecnicas de balanceo.

# %% [markdown]
# # Regresión Logística

# %%
modelo_base = make_pipeline(RobustScaler(), LogisticRegression(max_iter=150,random_state=42))
modelo_base.fit(X_train,y_train)

modelo_balanceado = make_pipeline(RobustScaler(), LogisticRegression(max_iter=150,random_state=42, class_weight='balanced'))
modelo_balanceado.fit(X_train,y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('robustscaler',
#                  RobustScaler(copy=True, quantile_range=(25.0, 75.0),
#                               unit_variance=False, with_centering=True,
#                               with_scaling=True)),
#                 ('logisticregression',
#                  LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=150,
#                                     multi_class='auto', n_jobs=None,
#                                     penalty='l2', random_state=42,
#                                     solver='lbfgs', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %% [markdown]
# Utilizamos el RobustScaler debido a que decidimos conservar los valores atipicos.

# %% [markdown]
# ## Modelo Base

# %%
def metricas(nombre_modelo,modelo,y_pred):
  metrics = {
    "Modelo": [
        nombre_modelo
    ],
    "Accuracy": [
        accuracy_score(y_test, y_pred)
    ],
    "Precision (No llueve)": [
      precision_score(y_test, y_pred, pos_label=0)
    ],
    "Precision (llueve)": [
      precision_score(y_test, y_pred, pos_label=1)
    ],
    "Recall (No llueve)": [
      recall_score(y_test, y_pred, pos_label=0)
    ],
    "Recall llueve": [
      recall_score(y_test, y_pred, pos_label=1)
    ],
    "F1 Score (No llueve)": [
      f1_score(y_test, y_pred, pos_label=0)
    ],
    "F1 Score (llueve)": [
      f1_score(y_test, y_pred, pos_label=1)
    ],
    "Kappa Score":[
      cohen_kappa_score(y_test,y_pred)
    ]
  }
  return pd.DataFrame(metrics)

# %%
y_pred_base = modelo_base.predict(X_test)
cf_m_base = confusion_matrix(y_test, y_pred_base)

plt.figure(figsize=(6, 4))
sns.heatmap(cf_m_base, annot=True, fmt="", cmap='Blues')
plt.title('Matriz de Confusión Modelo Base')
plt.xlabel('Predicción')
plt.ylabel('Verdadero')
plt.show()

# Obtenemos las probabilidades de predicción del modelo
y_probs = modelo_base.predict_proba(X_test)[:, 1]

# Calculamos la ROC y el AUC
fpr, tpr, thresholds = roc_curve(y_test, y_probs)
roc_auc = auc(fpr, tpr)

# Graficamos la curva ROC
plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='Curva ROC (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Tasa de Falsos Positivos (FPR)')
plt.ylabel('Tasa de Verdaderos Positivos (TPR)')
plt.title('Curva ROC')
plt.legend(loc="lower right")
plt.show()

#Metricas
metricas_base = metricas('Modelo Base',modelo_base,y_pred_base)
metricas_base
# Out:
#         Modelo  Accuracy  Precision (No llueve)  Precision (llueve)  \
# 0  Modelo Base  0.848724               0.870782            0.709637
#
#    Recall (No llueve)  Recall llueve  F1 Score (No llueve)  F1 Score (llueve)  \
# 0            0.949773       0.465517              0.908564           0.562221
#
#    Kappa Score
# 0     0.475512

# %% [markdown]
# TN cuando el modelo predice que no llueve y no llueve.
#
# FN cuando el modelo precice que no llueve y llueve.
#
# TP cuando el modelo predice que llueve y llueve.
#
# FP cuando el modelo predice que llueve y no llueve.
#
# Se observa que el modelo predice mejor cuando no llueve esto se debe a que tiende a predecir que no llueve por que los datos estan desbalanceados.
#
# En el F1 score se ve claramente como el modelo clasifica correctamente cuando no llueve (0.90) mientras que clasifica muy pobremente cuando llueve (0.54)

# %% [markdown]
# ## Modelo Balanceado

# %%
y_pred_balanceado = modelo_balanceado.predict(X_test)
cf_m_balanceado = confusion_matrix(y_test, y_pred_balanceado)

plt.figure(figsize=(6, 4))
sns.heatmap(cf_m_balanceado, annot=True, fmt="", cmap='Blues')
plt.title('Matriz de Confusión Modelo Balanceado')
plt.xlabel('Predicción')
plt.ylabel('Verdadero')
plt.show()

# Obtenemos las probabilidades de predicción del modelo
y_probs = modelo_balanceado.predict_proba(X_test)[:, 1]

# Calculamos la ROC y el AUC
fpr, tpr, thresholds = roc_curve(y_test, y_probs)
roc_auc = auc(fpr, tpr)

# Graficamos la curva ROC
plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='Curva ROC (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Tasa de Falsos Positivos (FPR)')
plt.ylabel('Tasa de Verdaderos Positivos (TPR)')
plt.title('Curva ROC')
plt.legend(loc="lower right")
plt.show()

#Metricas
metricas_balanceado = metricas('Modelo Balanceado',modelo_balanceado,y_pred_balanceado)
metricas_balanceado
# Out:
#               Modelo  Accuracy  Precision (No llueve)  Precision (llueve)  \
# 0  Modelo Balanceado  0.790475               0.932722            0.498693
#
#    Recall (No llueve)  Recall llueve  F1 Score (No llueve)  F1 Score (llueve)  \
# 0            0.792379       0.783251              0.856842            0.60939
#
#    Kappa Score
# 0       0.4757

# %% [markdown]
# En el modelo balanceado se observa como disminuye la cantidad de FN y aumentan los TP pero a cambio disminuye considerablemente los TN y aumentan los FP.

# %% [markdown]
# ## Modelo Base con regularización

# %%
modelo_base_reg = make_pipeline(RobustScaler(), LogisticRegression(max_iter=1750,random_state=42,penalty='l1', C=1, solver='saga'))
modelo_base_reg.fit(X_train,y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('robustscaler',
#                  RobustScaler(copy=True, quantile_range=(25.0, 75.0),
#                               unit_variance=False, with_centering=True,
#                               with_scaling=True)),
#                 ('logisticregression',
#                  LogisticRegression(C=1, class_weight=None, dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=1750,
#                                     multi_class='auto', n_jobs=None,
#                                     penalty='l1', random_state=42,
#                                     solver='saga', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %%
y_pred_base_reg = modelo_base_reg.predict(X_test)
cf_m_base_reg = confusion_matrix(y_test, y_pred_base_reg)

plt.figure(figsize=(6, 4))
sns.heatmap(cf_m_base_reg, annot=True, fmt="", cmap='Blues')
plt.title('Matriz de Confusión Modelo base reg')
plt.xlabel('Predicción')
plt.ylabel('Verdadero')
plt.show()

# Obtenemos las probabilidades de predicción del modelo
y_probs = modelo_base_reg.predict_proba(X_test)[:, 1]

# Calculamos la ROC y el AUC
fpr, tpr, thresholds = roc_curve(y_test, y_probs)
roc_auc = auc(fpr, tpr)

# Graficamos la curva ROC
plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='Curva ROC (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Tasa de Falsos Positivos (FPR)')
plt.ylabel('Tasa de Verdaderos Positivos (TPR)')
plt.title('Curva ROC')
plt.legend(loc="lower right")
plt.show()

#Metricas
metricas_base_reg = metricas('Modelo base reg',modelo_base_reg,y_pred_base_reg)
metricas_base_reg
# Out:
#             Modelo  Accuracy  Precision (No llueve)  Precision (llueve)  \
# 0  Modelo base reg  0.849066               0.870833            0.711418
#
#    Recall (No llueve)  Recall llueve  F1 Score (No llueve)  F1 Score (llueve)  \
# 0            0.950206       0.465517               0.90879           0.562779
#
#    Kappa Score
# 0     0.476338

# %%
oversampler = RandomOverSampler(random_state=42)
X_oversampled, y_oversampled = oversampler.fit_resample(X_train, y_train)
modelo_oversampled = make_pipeline(RobustScaler(), LogisticRegression(max_iter=150,random_state = 42))
modelo_oversampled.fit(X_oversampled,y_oversampled)
# Out:
# Pipeline(memory=None,
#          steps=[('robustscaler',
#                  RobustScaler(copy=True, quantile_range=(25.0, 75.0),
#                               unit_variance=False, with_centering=True,
#                               with_scaling=True)),
#                 ('logisticregression',
#                  LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=150,
#                                     multi_class='auto', n_jobs=None,
#                                     penalty='l2', random_state=42,
#                                     solver='lbfgs', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %%
y_pred_over = modelo_oversampled.predict(X_test)
cf_m_over = confusion_matrix(y_test, y_pred_over)

plt.figure(figsize=(6, 4))
sns.heatmap(cf_m_over, annot=True, fmt="", cmap='Blues')
plt.title('Matriz de Confusión Modelo oversampled')
plt.xlabel('Predicción')
plt.ylabel('Verdadero')
plt.show()

# Obtenemos las probabilidades de predicción del modelo
y_probs = modelo_oversampled.predict_proba(X_test)[:, 1]

# Calculamos la ROC y el AUC
fpr, tpr, thresholds = roc_curve(y_test, y_probs)
roc_auc = auc(fpr, tpr)

# Graficamos la curva ROC
plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='Curva ROC (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Tasa de Falsos Positivos (FPR)')
plt.ylabel('Tasa de Verdaderos Positivos (TPR)')
plt.title('Curva ROC')
plt.legend(loc="lower right")
plt.show()

#Metricas
metricas_over = metricas('Modelo oversampled',modelo_oversampled,y_pred_over)
metricas_over
# Out:
#                Modelo  Accuracy  Precision (No llueve)  Precision (llueve)  \
# 0  Modelo oversampled  0.791845               0.933741            0.500784
#
#    Recall (No llueve)  Recall llueve  F1 Score (No llueve)  F1 Score (llueve)  \
# 0            0.793245       0.786535              0.857778           0.611945
#
#    Kappa Score
# 0     0.479129

# %% [markdown]
# ## Modelo Random

# %%
modelo_random = make_pipeline(RobustScaler(), DummyClassifier(strategy="stratified",random_state=42))
modelo_random.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('robustscaler',
#                  RobustScaler(copy=True, quantile_range=(25.0, 75.0),
#                               unit_variance=False, with_centering=True,
#                               with_scaling=True)),
#                 ('dummyclassifier',
#                  DummyClassifier(constant=None, random_state=42,
#                                  strategy='stratified'))],
#          verbose=False)

# %%
y_pred_random = modelo_random.predict(X_test)
cf_m_random = confusion_matrix(y_test, y_pred_random)

plt.figure(figsize=(6, 4))
sns.heatmap(cf_m_random, annot=True, fmt="", cmap='Blues')
plt.title('Matriz de Confusión Modelo random')
plt.xlabel('Predicción')
plt.ylabel('Verdadero')
plt.show()

# Obtenemos las probabilidades de predicción del modelo
y_probs = modelo_random.predict_proba(X_test)[:, 1]

# Calculamos la ROC y el AUC
fpr, tpr, thresholds = roc_curve(y_test, y_probs)
roc_auc = auc(fpr, tpr)

# Graficamos la curva ROC
plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='Curva ROC (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Tasa de Falsos Positivos (FPR)')
plt.ylabel('Tasa de Verdaderos Positivos (TPR)')
plt.title('Curva ROC')
plt.legend(loc="lower right")
plt.show()

#Metricas
metricas_random = metricas('Modelo random',modelo_random,y_pred_random)
metricas_random
# Out:
#           Modelo  Accuracy  Precision (No llueve)  Precision (llueve)  \
# 0  Modelo random  0.668151               0.790889            0.207009
#
#    Recall (No llueve)  Recall llueve  F1 Score (No llueve)  F1 Score (llueve)  \
# 0            0.789348       0.208539              0.790118           0.207771
#
#    Kappa Score
# 0    -0.002107

# %% [markdown]
# ## Comparación de modelos

# %%
fig, axes = plt.subplots(2, 3, figsize=(12, 6))

# Títulos para cada subplot
titles = ['Modelo base', 'Modelo balanceado', 'Modelo regularizado', 'Modelo oversampling', 'Modelo random']
cf_matrices = [cf_m_base, cf_m_balanceado, cf_m_base_reg, cf_m_over,cf_m_random]
# Iteraramos sobre cada subplot y creamos un heatmap
for i, ax in zip(range(5), axes.flat):
    sns.heatmap(cf_matrices[i], annot=True, fmt="", cmap='Blues', ax=ax)
    ax.set_title(f'Matriz de Confusión {titles[i]}')
    ax.set_xlabel('Predicción')
    ax.set_ylabel('Verdadero')

# Ajustamos la visualización de los subplots
plt.tight_layout()
plt.show()

# %%
modelos = [modelo_base, modelo_balanceado, modelo_base_reg, modelo_oversampled, modelo_random]
fig, axes = plt.subplots(2, 3, figsize=(12, 6))

for i, ax in zip(range(5), axes.flat):
    # Obtenemos las probabilidades de predicción del modelo
    y_probs = modelos[i].predict_proba(X_test)[:, 1]

    # Calculamos la curva ROC y el AUC
    fpr, tpr, thresholds = roc_curve(y_test, y_probs)
    roc_auc = auc(fpr, tpr)

    # Calculamos el punto óptimo de umbral
    distancias = (fpr**2 + (1 - tpr)**2)**0.5
    indice_optimo = distancias.argmin()
    fpr_optimo, tpr_optimo = fpr[indice_optimo], tpr[indice_optimo]
    umbral_optimo = thresholds[indice_optimo]

    # Graficamos la curva ROC en el subplot específico
    ax.plot(fpr, tpr, color='darkorange', lw=2, label=f'Curva ROC (AUC = {roc_auc:.2f})')
    ax.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')

    # Graficamos el punto óptimo de umbral
    ax.plot(fpr_optimo, tpr_optimo, 'ro', label=f'Umbral Óptimo ({umbral_optimo:.2f})')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('Tasa de Falsos Positivos (FPR)')
    ax.set_ylabel('Tasa de Verdaderos Positivos (TPR)')
    ax.set_title(f'Curva ROC {titles[i]}')
    ax.legend(loc="lower right")

# Ajustamos el layout para que no haya solapamiento
plt.tight_layout()
plt.show()

# %%
# Mostramos una tabla comparativa de los modelos
comparacion = pd.concat([metricas_base, metricas_balanceado, metricas_base_reg, metricas_over,metricas_random], ignore_index=True)
comparacion
# Out:
#                Modelo  Accuracy  Precision (No llueve)  Precision (llueve)  \
# 0         Modelo Base  0.848724               0.870782            0.709637
# 1   Modelo Balanceado  0.790475               0.932722            0.498693
# 2     Modelo base reg  0.849066               0.870833            0.711418
# 3  Modelo oversampled  0.791845               0.933741            0.500784
# 4       Modelo random  0.668151               0.790889            0.207009
#
#    Recall (No llueve)  Recall llueve  F1 Score (No llueve)  F1 Score (llueve)  \
# 0            0.949773       0.465517              0.908564           0.562221
# 1            0.792379       0.783251              0.856842           0.609390
# 2            0.950206       0.465517              0.908790           0.562779
# 3            0.793245       0.786535              0.857778           0.611945
# 4            0.789348       0.208539              0.790118           0.207771
#
#    Kappa Score
# 0     0.475512
# 1     0.475700
# 2     0.476338
# 3     0.479129
# 4    -0.002107

# %% [markdown]
# # Conclusiones
# Los dos modelos no balanceados tienen resultados similares, estos tienen un mejor recall en la clase negativa (no llueve) en comparación a la clase positiva (llueve), esto es debido al desbalance que hay en los datos.
#
# Los modelos con balance de datos por otro lado tienen un recall similar tanto para la clase negativa como para la positiva pero si F1 score es solo levemente mejor que el de los modelos no balanceados para la clase positiva.
#
# El modelo random es el peor de todos ya que hace las clasificaciones al azar por ese motivo tiene un rendimiento muy bajo, ya que no puede encontrar relaciones en los datos.
#
# El AUC de todos los modeles expecto el random dieron resultados similares (aprox 0.86) un numero bastante cercano a 1 lo que indica un modelo con buen rendimiento en clasificación. Tambien se puede observar que el umbral optimo para los modelos balanceados es aprox 0.5 mientras que para los modelos no balanceados es de aprox 0.2, por lo que se puede decir que un umbral de 0.5 no es siempre el mas optimo.

# %% [markdown]
# # SHAP

# %%
feature_names = X_train.columns
explainer = shap.LinearExplainer(modelo_balanceado[1], X_train, feature_names=feature_names)
shap_values = explainer.shap_values(X_test)

# %% [markdown]
# ## Interpetabilidad local

# %%
y_test
# Out:
# 107026    0
# 55835     0
# 43520     0
# 107047    0
# 98944     0
#          ..
# 125195    0
# 131025    1
# 26008     0
# 57807     1
# 54554     1
# Name: RainTomorrow, Length: 5837, dtype: int64

# %%
index = 5836 #dia siguiente con lluvia
X_test_np = np.array(X_test)
explanation_local = shap.Explanation(values=shap_values[index], feature_names=feature_names,base_values=explainer.expected_value)

# %%
shap.force_plot(explanation_local,
                matplotlib=True, 
                figsize=(18, 4), 
                text_rotation=45)

# %%
shap.plots.bar(explanation_local, max_display=len(feature_names))

# %% [markdown]
# Se observa que en la predicción de un dia de lluvia las variables con mayor impacto fueron Humidity3pm, WinDir9am, WindGustSpeed, WindGustDir, Pressure3pm, WindDir3pm y Humidity9am
# Tambien se observa que la variable WinDir9am va en la dirección contraria empeorando la predicción.

# %% [markdown]
# ## Interpretabilidad global

# %%
explanation = shap.Explanation(values=shap_values, feature_names=feature_names,data=X_test_np)

# %%
shap.plots.beeswarm(explanation, max_display=len(feature_names))

# %%
print(len(df_ciudades))
df_ciudades.isna().sum()
# Out:
# 29183
# Location             0
# MinTemp             35
# MaxTemp             29
# Rainfall             0
# Evaporation      18180
# Sunshine         19195
# WindGustDir        584
# WindGustSpeed      584
# WindDir9am        1327
# WindDir3pm         374
# WindSpeed9am       152
# WindSpeed3pm       221
# Humidity9am        437
# Humidity3pm        364
# Pressure9am       8781
# Pressure3pm       8756
# Cloud9am         16113
# Cloud3pm         16918
# Temp9am            318
# Temp3pm            246
# RainToday            0
# RainTomorrow         0
# Month                0
# dtype: int64

# %%
shap.plots.bar(explanation, max_display=len(feature_names))

# %% [markdown]
# Se observa que las variables de direccion el modelo no logro aprender correctamente el funcionamiento de la variable ya que mientras menor el valor mas impacta en las probabilidad de lluvia y viceversa. Lo cual no tiene sentido por que las direcciones estan expresadas en grados y no tiene sentido que el grado 337.5 (NNW) indique la mayor probabilidad de lluvia y el grado 0 (N) indique la menor probabilidad de lluvia.
#
# Tambien se observa que las variables con una alta cantidad de valores faltantes en el dataset original tienen un bajo impacto en las predicciones del modelo esto sucede porque al tener tantos valores faltantes no se logra imputar correctamente los datos. (Evaporation, Sunshine, Cloud9am y Cloud3pm)
#
# Las variables latitud, longitud y month tienen muy poco impacto y podrian ser ignoradas
#
# La variable Rainfall no tiene un gran impacto pero cuando un dia tiene mucha lluvia tiene un impacto mayor en la prediccion de que el dia siguiente llueva. La variable RainToday es redundate teniendo Rainfall asi que puede ser ignorada.
#
# Las variables con mayor impacto son Humidity3pm, WindGustSpeed y Pressure3pm-9am

# %%
X_train.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'Month', 'Latitud', 'Longitud'],
#       dtype='object')

# %%
X_train_shap = X_train[['MinTemp','MaxTemp','Rainfall','WindGustSpeed','Humidity9am','Humidity3pm','Pressure9am','Pressure3pm','Temp9am','Temp3pm']]
X_test_shap =  X_test[['MinTemp','MaxTemp','Rainfall','WindGustSpeed','Humidity9am','Humidity3pm','Pressure9am','Pressure3pm','Temp9am','Temp3pm']]
X_oversampled_shap = X_oversampled[['MinTemp','MaxTemp','Rainfall','WindGustSpeed','Humidity9am','Humidity3pm','Pressure9am','Pressure3pm','Temp9am','Temp3pm']]

# %%
X_test_shap
# Out:
#         MinTemp  MaxTemp  Rainfall  WindGustSpeed  Humidity9am  Humidity3pm  \
# 107026     15.2     26.9       0.0           41.0         82.0         33.0
# 55835      14.3     28.0       5.0           43.0         83.0         51.0
# 43520      10.7     17.5       0.0           19.0         79.0         76.0
# 107047     13.0     23.3       0.0           31.0         59.0         31.0
# 98944      20.7     40.2       0.0           31.0         18.0         13.0
# ...         ...      ...       ...            ...          ...          ...
# 125195      7.4     28.2       0.0           46.0         61.0         26.0
# 131025      6.1     16.9       0.0           35.0         57.0         55.0
# 26008      10.6     29.4       0.0           39.0         81.0         28.0
# 57807       1.0      6.6       6.6           61.0        100.0         98.0
# 54554       8.0     12.5       0.0           54.0         95.0         98.0
#
#         Pressure9am  Pressure3pm  Temp9am  Temp3pm
# 107026      1023.30       1021.0     17.4     26.2
# 55835       1010.90       1009.8     19.7     26.4
# 43520       1024.20       1021.9     14.7     16.1
# 107047      1024.20       1021.4     17.4     22.4
# 98944       1015.30       1012.1     33.4     38.6
# ...             ...          ...      ...      ...
# 125195      1015.85       1014.0     20.9     27.0
# 131025      1020.80       1018.8     13.4     15.8
# 26008       1021.40       1019.0     17.3     29.3
# 57807       1013.10       1009.7      1.8      5.7
# 54554       1013.80       1011.9     11.6     12.3
#
# [5837 rows x 10 columns]

# %%
modelo_base.fit(X_train_shap,y_train)
modelo_base_reg.fit(X_train_shap,y_train)
modelo_balanceado.fit(X_train_shap,y_train)
modelo_random.fit(X_train_shap,y_train)
modelo_oversampled.fit(X_oversampled_shap,y_oversampled)

y_pred_base = modelo_base.predict(X_test_shap)
y_pred_base_reg = modelo_base_reg.predict(X_test_shap)
y_pred_balanceado = modelo_balanceado.predict(X_test_shap)
y_pred_random = modelo_random.predict(X_test_shap)
y_pred_over = modelo_oversampled.predict(X_test_shap)

metricas_base = metricas('Modelo base',modelo_base,y_pred_base)
metricas_base_reg = metricas('Modelo reg',modelo_base_reg,y_pred_base_reg)
metricas_balanceado = metricas('Modelo balanceado',modelo_balanceado,y_pred_balanceado)
metricas_random = metricas('Modelo random',modelo_random,y_pred_random)
metricas_over = metricas('Modelo oversampled',modelo_oversampled,y_pred_over)

comparacion_shap = pd.concat([metricas_base, metricas_balanceado, metricas_base_reg, metricas_over,metricas_random], ignore_index=True)

comparacion_shap
# Out:
#                Modelo  Accuracy  Precision (No llueve)  Precision (llueve)  \
# 0         Modelo base  0.837759               0.860566            0.681879
# 1   Modelo balanceado  0.780709               0.930839            0.484200
# 2          Modelo reg  0.838102               0.859914            0.686221
# 3  Modelo oversampled  0.780709               0.930616            0.484184
# 4       Modelo random  0.668151               0.790889            0.207009
#
#    Recall (No llueve)  Recall llueve  F1 Score (No llueve)  F1 Score (llueve)  \
# 0            0.948690       0.417077              0.902482           0.517575
# 1            0.780905       0.779967              0.849305           0.597484
# 2            0.950206       0.412972              0.902808           0.515633
# 3            0.781121       0.779146              0.849341           0.597231
# 4            0.789348       0.208539              0.790118           0.207771
#
#    Kappa Score
# 0     0.426784
# 1     0.457899
# 2     0.425564
# 3     0.457631
# 4    -0.002107

# %%
comparacion
# Out:
#                Modelo  Accuracy  Precision (No llueve)  Precision (llueve)  \
# 0         Modelo Base  0.848724               0.870782            0.709637
# 1   Modelo Balanceado  0.790475               0.932722            0.498693
# 2     Modelo base reg  0.849066               0.870833            0.711418
# 3  Modelo oversampled  0.791845               0.933741            0.500784
# 4       Modelo random  0.668151               0.790889            0.207009
#
#    Recall (No llueve)  Recall llueve  F1 Score (No llueve)  F1 Score (llueve)  \
# 0            0.949773       0.465517              0.908564           0.562221
# 1            0.792379       0.783251              0.856842           0.609390
# 2            0.950206       0.465517              0.908790           0.562779
# 3            0.793245       0.786535              0.857778           0.611945
# 4            0.789348       0.208539              0.790118           0.207771
#
#    Kappa Score
# 0     0.475512
# 1     0.475700
# 2     0.476338
# 3     0.479129
# 4    -0.002107

# %%
feature_names = X_train_shap.columns
explainer_2 = shap.LinearExplainer(modelo_base_reg[1], X_train_shap, feature_names=feature_names)
shap_values_2 = explainer_2.shap_values(X_test_shap)
X_test_np_2 = np.array(X_test_shap)
explanation_2 = shap.Explanation(values=shap_values_2, feature_names=feature_names,data=X_test_np_2)
shap.plots.beeswarm(explanation_2, max_display=len(feature_names))

# %% [markdown]
# Se puede observar que a pesar de tener un modelo mucho más simple se obtuvo resultados similares.

# %% [markdown]
# # Selección de hiperparámetros

# %% [markdown]
# Para la validación cruzada se eligio el metodo StratifiedKfold ya que este metodo divide en K particiones y entrena el modelo con K-1 particiones y usa la particion restante para testeo. Este metodo a diferencia del Kfold normal se asegura de que todas las particiones tengan la misma proporcion de clases.

# %%
#Se usa el dataset entero ya que Kfold va a hacer las divisiones
X_shap = pd.concat([X_train_shap, X_test_shap], axis=0)
y_shap = pd.concat([y_train, y_test], axis=0)
robust_scaler = RobustScaler().set_output(transform='pandas')
X_shap = robust_scaler.fit_transform(X_shap)
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
scores = cross_val_score(modelo_balanceado, X_shap, y_shap, cv=cv)
scores
# Out:
# array([0.77043002, 0.76734624, 0.77231455, 0.76662097, 0.76644962])

# %% [markdown]
# Para la optimizacion de los hiperparametros se eligio Optune ya que esta tecnica utiliza una busqueda mas inteligente en comparación a GridSearch que busca exhaustivamente todas las posibles combinaciones de los hiperparametros y que RandomSearch que evalua aleatoriamente un determinado rango de hiperparametros una cantidad predeterminada de veces. Optune realiza una busqueda de los mejores hiperparametros enfocandose en areas 'prometedoras' basandose en el rendimiento de busquedas previas. Ademas su funcionalidad de pruning que descarta las combinaciones que claramente no son efectivas ayuda a reducir considerablemente el tiempo total de busqueda, lo que es muy util en este dataset que contiene una gran cantidad de datos.
#
# Los hiperparametros que se busca optimizar son los siguientes:
#
# C: Parametro que controla cuánto regularización se aplica para evitar que el modelo se ajuste demasiado a los datos de entrenamiento. Mientras mayor C menos regularizacion
#
# Penalty: Se utiliza la regularizacion L2 porque queremos regularizar las variables actuales sin eliminar las variables actuales ya que previamente en el analisis shap eliminamos la mayoria de las variables.
#
# class_weight: Se Utiliza 'balanced' ya que queremos optimizar la prediccion de la clase 1 (lluvia)
#
# max_iter: Este parametro ajusta la cantidad de iteraciones en el entrenamiento del modelo.

# %%
def objective(trial):
    # Optimizamos la prediccion de la clase 1

    C = trial.suggest_float('C', 0.01, 1000)
    penalty = trial.suggest_categorical('penalty', ['l2'])
    class_weight = trial.suggest_categorical('class_weight', ['balanced'])
    max_iter = trial.suggest_int('max_iter', 100, 2000)  

    modelo_optuna = LogisticRegression(C=C, penalty=penalty, class_weight=class_weight, max_iter=max_iter)

    scorer = make_scorer(recall_score, average='binary') 
    
    recall_scores = cross_val_score(modelo_optuna, X_shap, y_shap, cv=cv, scoring=scorer)
    mean_recall = recall_scores.mean()

    return mean_recall

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)
best_optuna_params = study.best_params
best_optuna_model = make_pipeline(RobustScaler(),LogisticRegression(**best_optuna_params, random_state=42))
best_optuna_model.fit(X_train_shap, y_train)
y_pred_optuna = best_optuna_model.predict(X_test_shap)
print('Los mejores parametros son: ',study.best_params)
metricas('Modelo optuna',best_optuna_model,y_pred_optuna)
# Out:
# [I 2024-11-15 19:50:21,318] A new study created in memory with name: no-name-a2237b05-1594-447a-917e-8109f46f09ea
# [I 2024-11-15 19:50:21,625] Trial 0 finished with value: 0.7442542787286064 and parameters: {'C': 417.55781902135647, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 349}. Best is trial 0 with value: 0.7442542787286064.
# [I 2024-11-15 19:50:21,894] Trial 1 finished with value: 0.7442542787286064 and parameters: {'C': 346.60879688785934, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 346}. Best is trial 0 with value: 0.7442542787286064.
# [I 2024-11-15 19:50:22,159] Trial 2 finished with value: 0.7444172779136105 and parameters: {'C': 350.7398247959331, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 816}. Best is trial 2 with value: 0.7444172779136105.
# [I 2024-11-15 19:50:22,457] Trial 3 finished with value: 0.7444172779136105 and parameters: {'C': 770.0345033677479, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 766}. Best is trial 2 with value: 0.7444172779136105.
# [I 2024-11-15 19:50:22,753] Trial 4 finished with value: 0.7442542787286064 and parameters: {'C': 614.2581650136968, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 561}. Best is trial 2 with value: 0.7444172779136105.
# [I 2024-11-15 19:50:23,043] Trial 5 finished with value: 0.7442542787286064 and parameters: {'C': 543.0353018854707, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 634}. Best is trial 2 with value: 0.7444172779136105.
# [I 2024-11-15 19:50:23,335] Trial 6 finished with value: 0.7445802770986145 and parameters: {'C': 148.41948360348974, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1165}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:23,636] Trial 7 finished with value: 0.7442542787286064 and parameters: {'C': 815.298245595895, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 199}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:23,894] Trial 8 finished with value: 0.7444172779136105 and parameters: {'C': 365.86255110867677, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1263}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:24,177] Trial 9 finished with value: 0.7442542787286064 and parameters: {'C': 166.04704088673103, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1234}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:24,475] Trial 10 finished with value: 0.7444172779136105 and parameters: {'C': 104.79318227737144, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1934}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:24,764] Trial 11 finished with value: 0.7442542787286064 and parameters: {'C': 24.305565677780294, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1587}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:25,049] Trial 12 finished with value: 0.7444172779136105 and parameters: {'C': 230.4217264221192, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 955}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:25,338] Trial 13 finished with value: 0.7442542787286064 and parameters: {'C': 995.6705755511907, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1126}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:25,618] Trial 14 finished with value: 0.7442542787286064 and parameters: {'C': 248.1192586857618, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1525}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:25,907] Trial 15 finished with value: 0.7445802770986145 and parameters: {'C': 43.26781498955381, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 910}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:26,201] Trial 16 finished with value: 0.7444172779136105 and parameters: {'C': 64.09247753469322, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1545}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:26,489] Trial 17 finished with value: 0.7444172779136105 and parameters: {'C': 13.799781841182856, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 985}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:26,802] Trial 18 finished with value: 0.7442542787286064 and parameters: {'C': 247.84654573105223, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1353}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:27,124] Trial 19 finished with value: 0.7445802770986145 and parameters: {'C': 133.75958882331685, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1830}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:27,401] Trial 20 finished with value: 0.7442542787286064 and parameters: {'C': 456.54850134827336, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 853}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:27,730] Trial 21 finished with value: 0.7445802770986145 and parameters: {'C': 153.56118047682403, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1909}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:28,019] Trial 22 finished with value: 0.7445802770986145 and parameters: {'C': 145.08780002081585, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1797}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:28,313] Trial 23 finished with value: 0.7442542787286064 and parameters: {'C': 228.87971061959604, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1659}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:28,602] Trial 24 finished with value: 0.7440912795436022 and parameters: {'C': 0.6155899967543519, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1406}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:28,902] Trial 25 finished with value: 0.7442542787286064 and parameters: {'C': 124.92880797173808, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1113}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:29,199] Trial 26 finished with value: 0.7442542787286064 and parameters: {'C': 73.76176332283455, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 629}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:29,485] Trial 27 finished with value: 0.7442542787286064 and parameters: {'C': 294.05494835388754, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1710}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:29,778] Trial 28 finished with value: 0.7442542787286064 and parameters: {'C': 178.40558302254126, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1415}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:30,058] Trial 29 finished with value: 0.7442542787286064 and parameters: {'C': 451.1976065445359, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1199}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:30,345] Trial 30 finished with value: 0.7442542787286064 and parameters: {'C': 294.59993521332444, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 448}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:30,643] Trial 31 finished with value: 0.7442542787286064 and parameters: {'C': 96.59219522513783, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1963}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:30,927] Trial 32 finished with value: 0.7444172779136105 and parameters: {'C': 179.4109259537592, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1838}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:31,230] Trial 33 finished with value: 0.7444172779136105 and parameters: {'C': 75.16241759797396, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1828}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:31,505] Trial 34 finished with value: 0.7444172779136105 and parameters: {'C': 299.1517709233853, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 882}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:31,783] Trial 35 finished with value: 0.7444172779136105 and parameters: {'C': 358.51340066449376, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1963}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:32,056] Trial 36 finished with value: 0.7442542787286064 and parameters: {'C': 581.2624986269866, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 779}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:32,338] Trial 37 finished with value: 0.7442542787286064 and parameters: {'C': 192.08747742208533, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1718}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:32,630] Trial 38 finished with value: 0.7442542787286064 and parameters: {'C': 738.5395341906731, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 184}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:32,925] Trial 39 finished with value: 0.7444172779136105 and parameters: {'C': 51.278803309602736, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 703}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:33,213] Trial 40 finished with value: 0.7442542787286064 and parameters: {'C': 396.7446064982938, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 286}. Best is trial 6 with value: 0.7445802770986145.
# [I 2024-11-15 19:50:33,522] Trial 41 finished with value: 0.7447432762836186 and parameters: {'C': 139.47973673786078, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1838}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:33,827] Trial 42 finished with value: 0.7444172779136105 and parameters: {'C': 129.94823837089086, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1856}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:34,124] Trial 43 finished with value: 0.7442542787286064 and parameters: {'C': 201.43886980791103, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1646}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:34,429] Trial 44 finished with value: 0.7442542787286064 and parameters: {'C': 100.46634932985191, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1994}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:34,721] Trial 45 finished with value: 0.7444172779136105 and parameters: {'C': 155.41684171971957, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1744}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:35,022] Trial 46 finished with value: 0.7444172779136105 and parameters: {'C': 42.02932375053204, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1490}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:35,309] Trial 47 finished with value: 0.7442542787286064 and parameters: {'C': 305.4797145885269, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1038}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:35,593] Trial 48 finished with value: 0.7444172779136105 and parameters: {'C': 978.8970256659242, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 489}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:35,865] Trial 49 finished with value: 0.7445802770986145 and parameters: {'C': 266.41993018208836, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1889}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:36,202] Trial 50 finished with value: 0.7444172779136105 and parameters: {'C': 221.51715036216865, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1283}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:36,495] Trial 51 finished with value: 0.7444172779136105 and parameters: {'C': 134.08908693095998, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1787}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:36,783] Trial 52 finished with value: 0.7445802770986145 and parameters: {'C': 153.92047364671186, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1606}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:37,080] Trial 53 finished with value: 0.7442542787286064 and parameters: {'C': 41.74366201966734, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1789}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:37,370] Trial 54 finished with value: 0.7442542787286064 and parameters: {'C': 114.0434029709114, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 912}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:37,668] Trial 55 finished with value: 0.7444172779136105 and parameters: {'C': 78.69974580552848, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1921}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:37,984] Trial 56 finished with value: 0.7442542787286064 and parameters: {'C': 649.3505836952174, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1679}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:38,298] Trial 57 finished with value: 0.7444172779136105 and parameters: {'C': 1.1605809328914773, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1780}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:38,616] Trial 58 finished with value: 0.7442542787286064 and parameters: {'C': 204.3721186241037, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1581}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:38,902] Trial 59 finished with value: 0.7444172779136105 and parameters: {'C': 259.6592322335416, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1147}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:39,183] Trial 60 finished with value: 0.7445802770986145 and parameters: {'C': 153.073804596644, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1482}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:39,458] Trial 61 finished with value: 0.7442542787286064 and parameters: {'C': 251.81713807718012, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1909}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:39,731] Trial 62 finished with value: 0.7442542787286064 and parameters: {'C': 332.72250705867407, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1880}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:40,047] Trial 63 finished with value: 0.7442542787286064 and parameters: {'C': 104.20920344333527, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1861}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:40,348] Trial 64 finished with value: 0.7442542787286064 and parameters: {'C': 172.99302460925924, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 969}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:40,641] Trial 65 finished with value: 0.7445802770986145 and parameters: {'C': 267.9597774941068, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1990}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:40,945] Trial 66 finished with value: 0.7442542787286064 and parameters: {'C': 33.52373070110362, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1745}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:41,248] Trial 67 finished with value: 0.7444172779136105 and parameters: {'C': 74.60842967426477, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1052}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:41,549] Trial 68 finished with value: 0.7442542787286064 and parameters: {'C': 218.66920427949316, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1905}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:41,845] Trial 69 finished with value: 0.7445802770986145 and parameters: {'C': 135.55138380576017, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 119}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:42,121] Trial 70 finished with value: 0.7444172779136105 and parameters: {'C': 473.83634649075606, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 712}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:42,397] Trial 71 finished with value: 0.7444172779136105 and parameters: {'C': 160.35746242342543, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1643}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:42,665] Trial 72 finished with value: 0.7445802770986145 and parameters: {'C': 146.00342906102912, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1601}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:42,966] Trial 73 finished with value: 0.7442542787286064 and parameters: {'C': 186.24243941184028, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1821}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:43,280] Trial 74 finished with value: 0.7445802770986145 and parameters: {'C': 82.71445357024544, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1692}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:43,571] Trial 75 finished with value: 0.7442542787286064 and parameters: {'C': 114.67413887101685, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1926}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:43,840] Trial 76 finished with value: 0.7442542787286064 and parameters: {'C': 18.18697080273003, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1758}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:44,102] Trial 77 finished with value: 0.7444172779136105 and parameters: {'C': 390.4627850254697, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1817}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:44,376] Trial 78 finished with value: 0.7442542787286064 and parameters: {'C': 277.72523246846, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1400}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:44,644] Trial 79 finished with value: 0.7442542787286064 and parameters: {'C': 327.31341126005725, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1613}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:44,929] Trial 80 finished with value: 0.7442542787286064 and parameters: {'C': 228.05115656595942, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 820}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:45,199] Trial 81 finished with value: 0.7442542787286064 and parameters: {'C': 155.63180086088434, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1478}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:45,500] Trial 82 finished with value: 0.7444172779136105 and parameters: {'C': 63.67105518503193, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1324}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:45,773] Trial 83 finished with value: 0.7445802770986145 and parameters: {'C': 128.8489388858468, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1532}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:46,049] Trial 84 finished with value: 0.7442542787286064 and parameters: {'C': 176.00244165207866, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1952}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:46,329] Trial 85 finished with value: 0.7442542787286064 and parameters: {'C': 201.73338696343154, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1711}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:46,629] Trial 86 finished with value: 0.7442542787286064 and parameters: {'C': 89.60132126351803, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1449}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:46,932] Trial 87 finished with value: 0.7440912795436023 and parameters: {'C': 53.580797480409494, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1225}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:47,203] Trial 88 finished with value: 0.7442542787286064 and parameters: {'C': 533.2732888046528, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1564}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:47,473] Trial 89 finished with value: 0.7444172779136105 and parameters: {'C': 157.35792532558548, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1883}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:47,757] Trial 90 finished with value: 0.7442542787286064 and parameters: {'C': 107.14817530833659, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1834}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:48,046] Trial 91 finished with value: 0.7444172779136105 and parameters: {'C': 273.6899036078836, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1871}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:48,328] Trial 92 finished with value: 0.7442542787286064 and parameters: {'C': 246.5271115557125, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1942}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:48,623] Trial 93 finished with value: 0.7447432762836186 and parameters: {'C': 143.65709753023026, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1995}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:48,941] Trial 94 finished with value: 0.7444172779136105 and parameters: {'C': 141.31805497812434, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1797}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:49,249] Trial 95 finished with value: 0.7442542787286064 and parameters: {'C': 203.77664495547924, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1995}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:49,554] Trial 96 finished with value: 0.7444172779136105 and parameters: {'C': 117.17808381528693, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1737}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:49,838] Trial 97 finished with value: 0.7442542787286064 and parameters: {'C': 170.03941784586863, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1657}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:50,117] Trial 98 finished with value: 0.7442542787286064 and parameters: {'C': 54.63425684349018, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 915}. Best is trial 41 with value: 0.7447432762836186.
# [I 2024-11-15 19:50:50,402] Trial 99 finished with value: 0.7444172779136105 and parameters: {'C': 23.62413819921383, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1060}. Best is trial 41 with value: 0.7447432762836186.
# Los mejores parametros son:  {'C': 139.47973673786078, 'penalty': 'l2', 'class_weight': 'balanced', 'max_iter': 1838}
#           Modelo  Accuracy  Precision (No llueve)  Precision (llueve)  \
# 0  Modelo optuna  0.781052               0.931097            0.484709
#
#    Recall (No llueve)  Recall llueve  F1 Score (No llueve)  F1 Score (llueve)  \
# 0            0.781121       0.780788              0.849541           0.598113
#
#    Kappa Score
# 0     0.458746

# %%
comparacion_shap
# Out:
#                Modelo  Accuracy  Precision (No llueve)  Precision (llueve)  \
# 0         Modelo base  0.837759               0.860566            0.681879
# 1   Modelo balanceado  0.780709               0.930839            0.484200
# 2          Modelo reg  0.838102               0.859914            0.686221
# 3  Modelo oversampled  0.780709               0.930616            0.484184
# 4       Modelo random  0.668151               0.790889            0.207009
#
#    Recall (No llueve)  Recall llueve  F1 Score (No llueve)  F1 Score (llueve)  \
# 0            0.948690       0.417077              0.902482           0.517575
# 1            0.780905       0.779967              0.849305           0.597484
# 2            0.950206       0.412972              0.902808           0.515633
# 3            0.781121       0.779146              0.849341           0.597231
# 4            0.789348       0.208539              0.790118           0.207771
#
#    Kappa Score
# 0     0.426784
# 1     0.457899
# 2     0.425564
# 3     0.457631
# 4    -0.002107

# %% [markdown]
# Se obseva que se obtuvo resultados similares al modelo balanceado, esto se debe a que se obtuvo un valor del hiperparametro 'C' muy elevado lo que hace disminuir la regularización que se aplica quedando un modelo muy parecido al 'Modelo balanceado' utilizado previamente.

# %% [markdown]
# # AutoML

# %%
# Usamos el dataset previo con las ciudades seleccionadas y previo a la imputaciones de los datos faltantes
clf_pycaret = setup(data=df_ciudades, target='RainTomorrow', session_id=42, fix_imbalance=True)
# Out:
# <style type="text/css">
# #T_ed20e_row11_col1, #T_ed20e_row17_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ed20e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ed20e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ed20e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed20e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ed20e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ed20e_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_ed20e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ed20e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ed20e_row1_col1" class="data row1 col1" >RainTomorrow</td>
#     </tr>
#     <tr>
#       <th id="T_ed20e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ed20e_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_ed20e_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_ed20e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ed20e_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_ed20e_row3_col1" class="data row3 col1" >No: 0, Yes: 1</td>
#     </tr>
#     <tr>
#       <th id="T_ed20e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ed20e_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_ed20e_row4_col1" class="data row4 col1" >(29183, 23)</td>
#     </tr>
#     <tr>
#       <th id="T_ed20e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ed20e_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_ed20e_row5_col1" class="data row5 col1" >(41023, 77)</td>
#     </tr>
#     <tr>
#       <th id="T_ed20e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ed20e_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_ed20e_row6_col1" class="data row6 col1" >(32268, 77)</td>
#     </tr>
#     <tr>
#       <th id="T_ed20e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ed20e_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_ed20e_row7_col1" class="data row7 col1" >(8755, 77)</td>
#     </tr>
#     <tr>
#       <th id="T_ed20e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ed20e_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_ed20e_row8_col1" class="data row8 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_ed20e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ed20e_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_ed20e_row9_col1" class="data row9 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_ed20e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ed20e_row10_col0" class="data row10 col0" >Rows with missing values</td>
#       <td id="T_ed20e_row10_col1" class="data row10 col1" >77.6%</td>
#     </tr>
#     <tr>
#       <th id="T_ed20e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ed20e_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_ed20e_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ed20e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ed20e_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_ed20e_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_ed20e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ed20e_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_ed20e_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_ed20e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ed20e_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_ed20e_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_ed20e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ed20e_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_ed20e_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_ed20e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ed20e_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_ed20e_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_ed20e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_ed20e_row17_col0" class="data row17 col0" >Fix imbalance</td>
#       <td id="T_ed20e_row17_col1" class="data row17 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ed20e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_ed20e_row18_col0" class="data row18 col0" >Fix imbalance method</td>
#       <td id="T_ed20e_row18_col1" class="data row18 col1" >SMOTE</td>
#     </tr>
#     <tr>
#       <th id="T_ed20e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_ed20e_row19_col0" class="data row19 col0" >Fold Generator</td>
#       <td id="T_ed20e_row19_col1" class="data row19 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_ed20e_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_ed20e_row20_col0" class="data row20 col0" >Fold Number</td>
#       <td id="T_ed20e_row20_col1" class="data row20 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_ed20e_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_ed20e_row21_col0" class="data row21 col0" >CPU Jobs</td>
#       <td id="T_ed20e_row21_col1" class="data row21 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_ed20e_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_ed20e_row22_col0" class="data row22 col0" >Use GPU</td>
#       <td id="T_ed20e_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ed20e_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_ed20e_row23_col0" class="data row23 col0" >Log Experiment</td>
#       <td id="T_ed20e_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ed20e_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_ed20e_row24_col0" class="data row24 col0" >Experiment Name</td>
#       <td id="T_ed20e_row24_col1" class="data row24 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_ed20e_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_ed20e_row25_col0" class="data row25 col0" >USI</td>
#       <td id="T_ed20e_row25_col1" class="data row25 col1" >b247</td>
#     </tr>
#   </tbody>
# </table>

# %%
modelo_mlauto = compare_models(sort='Kappa')
# Out:
# <style type="text/css">
# #T_0af7f th {
#   text-align: left;
# }
# #T_0af7f_row0_col0, #T_0af7f_row1_col0, #T_0af7f_row1_col1, #T_0af7f_row1_col2, #T_0af7f_row1_col3, #T_0af7f_row1_col4, #T_0af7f_row1_col5, #T_0af7f_row1_col6, #T_0af7f_row1_col7, #T_0af7f_row2_col0, #T_0af7f_row2_col1, #T_0af7f_row2_col2, #T_0af7f_row2_col3, #T_0af7f_row2_col4, #T_0af7f_row2_col5, #T_0af7f_row2_col6, #T_0af7f_row2_col7, #T_0af7f_row3_col0, #T_0af7f_row3_col1, #T_0af7f_row3_col2, #T_0af7f_row3_col3, #T_0af7f_row3_col4, #T_0af7f_row3_col5, #T_0af7f_row3_col6, #T_0af7f_row3_col7, #T_0af7f_row4_col0, #T_0af7f_row4_col1, #T_0af7f_row4_col2, #T_0af7f_row4_col3, #T_0af7f_row4_col4, #T_0af7f_row4_col5, #T_0af7f_row4_col6, #T_0af7f_row4_col7, #T_0af7f_row5_col0, #T_0af7f_row5_col1, #T_0af7f_row5_col2, #T_0af7f_row5_col3, #T_0af7f_row5_col4, #T_0af7f_row5_col5, #T_0af7f_row5_col6, #T_0af7f_row5_col7, #T_0af7f_row6_col0, #T_0af7f_row6_col1, #T_0af7f_row6_col2, #T_0af7f_row6_col3, #T_0af7f_row6_col4, #T_0af7f_row6_col5, #T_0af7f_row6_col6, #T_0af7f_row6_col7, #T_0af7f_row7_col0, #T_0af7f_row7_col1, #T_0af7f_row7_col2, #T_0af7f_row7_col3, #T_0af7f_row7_col4, #T_0af7f_row7_col5, #T_0af7f_row7_col6, #T_0af7f_row7_col7, #T_0af7f_row8_col0, #T_0af7f_row8_col1, #T_0af7f_row8_col2, #T_0af7f_row8_col3, #T_0af7f_row8_col4, #T_0af7f_row8_col5, #T_0af7f_row8_col6, #T_0af7f_row8_col7, #T_0af7f_row9_col0, #T_0af7f_row9_col1, #T_0af7f_row9_col2, #T_0af7f_row9_col3, #T_0af7f_row9_col4, #T_0af7f_row9_col5, #T_0af7f_row9_col6, #T_0af7f_row9_col7, #T_0af7f_row10_col0, #T_0af7f_row10_col1, #T_0af7f_row10_col2, #T_0af7f_row10_col3, #T_0af7f_row10_col4, #T_0af7f_row10_col5, #T_0af7f_row10_col6, #T_0af7f_row10_col7, #T_0af7f_row11_col0, #T_0af7f_row11_col1, #T_0af7f_row11_col2, #T_0af7f_row11_col3, #T_0af7f_row11_col4, #T_0af7f_row11_col5, #T_0af7f_row11_col6, #T_0af7f_row11_col7, #T_0af7f_row12_col0, #T_0af7f_row12_col1, #T_0af7f_row12_col2, #T_0af7f_row12_col3, #T_0af7f_row12_col4, #T_0af7f_row12_col5, #T_0af7f_row12_col6, #T_0af7f_row12_col7, #T_0af7f_row13_col0, #T_0af7f_row13_col1, #T_0af7f_row13_col2, #T_0af7f_row13_col3, #T_0af7f_row13_col4, #T_0af7f_row13_col5, #T_0af7f_row13_col6, #T_0af7f_row13_col7 {
#   text-align: left;
# }
# #T_0af7f_row0_col1, #T_0af7f_row0_col2, #T_0af7f_row0_col3, #T_0af7f_row0_col4, #T_0af7f_row0_col5, #T_0af7f_row0_col6, #T_0af7f_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_0af7f_row0_col8, #T_0af7f_row1_col8, #T_0af7f_row2_col8, #T_0af7f_row3_col8, #T_0af7f_row4_col8, #T_0af7f_row5_col8, #T_0af7f_row6_col8, #T_0af7f_row7_col8, #T_0af7f_row8_col8, #T_0af7f_row9_col8, #T_0af7f_row10_col8, #T_0af7f_row11_col8, #T_0af7f_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_0af7f_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_0af7f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0af7f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0af7f_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_0af7f_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_0af7f_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_0af7f_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_0af7f_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_0af7f_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_0af7f_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_0af7f_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0af7f_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_0af7f_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_0af7f_row0_col1" class="data row0 col1" >0.8541</td>
#       <td id="T_0af7f_row0_col2" class="data row0 col2" >0.8747</td>
#       <td id="T_0af7f_row0_col3" class="data row0 col3" >0.8541</td>
#       <td id="T_0af7f_row0_col4" class="data row0 col4" >0.8447</td>
#       <td id="T_0af7f_row0_col5" class="data row0 col5" >0.8458</td>
#       <td id="T_0af7f_row0_col6" class="data row0 col6" >0.5149</td>
#       <td id="T_0af7f_row0_col7" class="data row0 col7" >0.5236</td>
#       <td id="T_0af7f_row0_col8" class="data row0 col8" >0.3260</td>
#     </tr>
#     <tr>
#       <th id="T_0af7f_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_0af7f_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_0af7f_row1_col1" class="data row1 col1" >0.8531</td>
#       <td id="T_0af7f_row1_col2" class="data row1 col2" >0.8677</td>
#       <td id="T_0af7f_row1_col3" class="data row1 col3" >0.8531</td>
#       <td id="T_0af7f_row1_col4" class="data row1 col4" >0.8437</td>
#       <td id="T_0af7f_row1_col5" class="data row1 col5" >0.8451</td>
#       <td id="T_0af7f_row1_col6" class="data row1 col6" >0.5135</td>
#       <td id="T_0af7f_row1_col7" class="data row1 col7" >0.5214</td>
#       <td id="T_0af7f_row1_col8" class="data row1 col8" >0.7810</td>
#     </tr>
#     <tr>
#       <th id="T_0af7f_level0_row2" class="row_heading level0 row2" >gbc</th>
#       <td id="T_0af7f_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#       <td id="T_0af7f_row2_col1" class="data row2 col1" >0.8442</td>
#       <td id="T_0af7f_row2_col2" class="data row2 col2" >0.8585</td>
#       <td id="T_0af7f_row2_col3" class="data row2 col3" >0.8442</td>
#       <td id="T_0af7f_row2_col4" class="data row2 col4" >0.8379</td>
#       <td id="T_0af7f_row2_col5" class="data row2 col5" >0.8403</td>
#       <td id="T_0af7f_row2_col6" class="data row2 col6" >0.5081</td>
#       <td id="T_0af7f_row2_col7" class="data row2 col7" >0.5100</td>
#       <td id="T_0af7f_row2_col8" class="data row2 col8" >1.6230</td>
#     </tr>
#     <tr>
#       <th id="T_0af7f_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_0af7f_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#       <td id="T_0af7f_row3_col1" class="data row3 col1" >0.8539</td>
#       <td id="T_0af7f_row3_col2" class="data row3 col2" >0.8661</td>
#       <td id="T_0af7f_row3_col3" class="data row3 col3" >0.8539</td>
#       <td id="T_0af7f_row3_col4" class="data row3 col4" >0.8438</td>
#       <td id="T_0af7f_row3_col5" class="data row3 col5" >0.8426</td>
#       <td id="T_0af7f_row3_col6" class="data row3 col6" >0.4998</td>
#       <td id="T_0af7f_row3_col7" class="data row3 col7" >0.5145</td>
#       <td id="T_0af7f_row3_col8" class="data row3 col8" >0.6410</td>
#     </tr>
#     <tr>
#       <th id="T_0af7f_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_0af7f_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#       <td id="T_0af7f_row4_col1" class="data row4 col1" >0.8199</td>
#       <td id="T_0af7f_row4_col2" class="data row4 col2" >0.8329</td>
#       <td id="T_0af7f_row4_col3" class="data row4 col3" >0.8199</td>
#       <td id="T_0af7f_row4_col4" class="data row4 col4" >0.8223</td>
#       <td id="T_0af7f_row4_col5" class="data row4 col5" >0.8210</td>
#       <td id="T_0af7f_row4_col6" class="data row4 col6" >0.4642</td>
#       <td id="T_0af7f_row4_col7" class="data row4 col7" >0.4644</td>
#       <td id="T_0af7f_row4_col8" class="data row4 col8" >0.4450</td>
#     </tr>
#     <tr>
#       <th id="T_0af7f_level0_row5" class="row_heading level0 row5" >lda</th>
#       <td id="T_0af7f_row5_col0" class="data row5 col0" >Linear Discriminant Analysis</td>
#       <td id="T_0af7f_row5_col1" class="data row5 col1" >0.7896</td>
#       <td id="T_0af7f_row5_col2" class="data row5 col2" >0.8560</td>
#       <td id="T_0af7f_row5_col3" class="data row5 col3" >0.7896</td>
#       <td id="T_0af7f_row5_col4" class="data row5 col4" >0.8331</td>
#       <td id="T_0af7f_row5_col5" class="data row5 col5" >0.8030</td>
#       <td id="T_0af7f_row5_col6" class="data row5 col6" >0.4631</td>
#       <td id="T_0af7f_row5_col7" class="data row5 col7" >0.4800</

# %%
plot_model(modelo_mlauto, plot = 'confusion_matrix')

# %%
plot_model(modelo_mlauto, plot='auc')

# %%
predict_model(modelo_mlauto)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8b681">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b681_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8b681_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_8b681_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_8b681_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_8b681_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_8b681_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_8b681_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_8b681_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b681_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8b681_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_8b681_row0_col1" class="data row0 col1" >0.8514</td>
#       <td id="T_8b681_row0_col2" class="data row0 col2" >0.8659</td>
#       <td id="T_8b681_row0_col3" class="data row0 col3" >0.8514</td>
#       <td id="T_8b681_row0_col4" class="data row0 col4" >0.8419</td>
#       <td id="T_8b681_row0_col5" class="data row0 col5" >0.8435</td>
#       <td id="T_8b681_row0_col6" class="data row0 col6" >0.5093</td>
#       <td id="T_8b681_row0_col7" class="data row0 col7" >0.5165</td>
#     </tr>
#   </tbody>
# </table>
#            Location    MinTemp    MaxTemp   Rainfall  Evaporation  Sunshine  \
# 53079   MountGinini   1.200000  14.200000   0.000000          NaN       NaN
# 132645       Hobart   2.100000  17.000000  15.400000          1.6       0.0
# 45284    Wollongong   8.700000  18.400000   0.000000          NaN       NaN
# 132884       Hobart  15.400000  25.200001   0.000000          6.0       5.7
# 105757      Woomera   5.800000  15.700000   5.800000          2.2       7.8
# ...             ...        ...        ...        ...          ...       ...
# 108060      Woomera  19.100000  40.500000   0.000000         15.4      10.2
# 96356      Adelaide   7.400000  11.900000   1.200000          0.4       0.5
# 107174      Woomera  13.700000  22.299999   1.600000          5.8      10.7
# 106749      Woomera  10.600000  19.299999   0.000000          8.0      10.6
# 43032    Wollongong  17.299999  20.900000  97.199997          NaN       NaN
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Pressure3pm  \
# 53079          NNE           35.0        NNE          N  ...          NaN
# 132645          NE           61.0        NNE          N  ...  1008.299988
# 45284           NW           48.0        WNW        ENE  ...  1019.500000
# 132884          NW           57.0        NNW        WNW  ...   995.799988
# 105757          SW           37.0        WSW         SW  ...  1016.500000
# ...            ...            ...        ...        ...  ...          ...
# 108060         NNW           81.0          E          N  ...   999.900024
# 96356          WSW           48.0          N          N  ...  1016.799988
# 107174          NW           94.0        WNW          W  ...  1010.599976
# 106749         SSE           52.0        SSE         SE  ...  1025.099976
# 43032          SSE           59.0         SW        SSW  ...  1018.900024
#
#         Cloud9am  Cloud3pm    Temp9am    Temp3pm  RainToday  Month  \
# 53079        NaN       NaN   7.000000   9.500000         No     10
# 132645       7.0       7.0  16.100000  15.400000        Yes      6
# 45284        NaN       NaN  13.400000  17.200001         No      8
# 132884       8.0       6.0  17.500000  24.600000         No      1
# 105757       1.0       5.0   8.800000  13.900000        Yes      7
# ...          ...       ...        ...        ...        ...    ...
# 108060       1.0       2.0  25.100000  38.599998         No      2
# 96356        NaN       NaN  10.000000   9.500000        Yes      8
# 107174       0.0       1.0  16.100000  21.400000        Yes      8
# 106749       0.0       0.0  14.300000  18.700001         No      5
# 43032        8.0       8.0  17.799999  19.000000        Yes      3
#
#         RainTomorrow  prediction_label  prediction_score
# 53079             No                No            0.6797
# 132645           Yes               Yes            0.9099
# 45284             No                No            0.9446
# 132884           Yes               Yes            0.5930
# 105757            No                No            0.8456
# ...              ...               ...               ...
# 108060           Yes                No            0.8759
# 96356            Yes               Yes            0.9613
# 107174            No                No            0.9713
# 106749            No                No            0.9845
# 43032             No               Yes            0.8717
#
# [8755 rows x 25 columns]

# %%
comparacion_shap
# Out:
#                Modelo  Accuracy  Precision (No llueve)  Precision (llueve)  \
# 0         Modelo base  0.837759               0.860566            0.681879
# 1   Modelo balanceado  0.780709               0.930839            0.484200
# 2          Modelo reg  0.838102               0.859914            0.686221
# 3  Modelo oversampled  0.780709               0.930616            0.484184
# 4       Modelo random  0.668151               0.790889            0.207009
#
#    Recall (No llueve)  Recall llueve  F1 Score (No llueve)  F1 Score (llueve)  \
# 0            0.948690       0.417077              0.902482           0.517575
# 1            0.780905       0.779967              0.849305           0.597484
# 2            0.950206       0.412972              0.902808           0.515633
# 3            0.781121       0.779146              0.849341           0.597231
# 4            0.789348       0.208539              0.790118           0.207771
#
#    Kappa Score
# 0     0.426784
# 1     0.457899
# 2     0.425564
# 3     0.457631
# 4    -0.002107

# %%
print(modelo_mlauto.feature_name_)
# Out:
# ['Location_Williamtown', 'Location_SalmonGums', 'Location_Penrith', 'Location_Woomera', 'Location_Adelaide', 'Location_Sale', 'Location_Ballarat', 'Location_MountGinini', 'Location_Hobart', 'Location_Wollongong', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustDir_E', 'WindGustDir_SSE', 'WindGustDir_SE', 'WindGustDir_ENE', 'WindGustDir_WNW', 'WindGustDir_ESE', 'WindGustDir_N', 'WindGustDir_WSW', 'WindGustDir_W', 'WindGustDir_SW', 'WindGustDir_NW', 'WindGustDir_SSW', 'WindGustDir_NNE', 'WindGustDir_S', 'WindGustDir_NNW', 'WindGustDir_NE', 'WindGustSpeed', 'WindDir9am_SW', 'WindDir9am_SSW', 'WindDir9am_SSE', 'WindDir9am_WNW', 'WindDir9am_NW', 'WindDir9am_N', 'WindDir9am_WSW', 'WindDir9am_W', 'WindDir9am_NNW', 'WindDir9am_S', 'WindDir9am_NE', 'WindDir9am_SE', 'WindDir9am_NNE', 'WindDir9am_ESE', 'WindDir9am_E', 'WindDir9am_ENE', 'WindDir3pm_SE', 'WindDir3pm_SSE', 'WindDir3pm_ESE', 'WindDir3pm_NNW', 'WindDir3pm_W', 'WindDir3pm_E', 'WindDir3pm_WNW', 'WindDir3pm_NNE', 'WindDir3pm_SW', 'WindDir3pm_WSW', 'WindDir3pm_NW', 'WindDir3pm_N', 'WindDir3pm_NE', 'WindDir3pm_SSW', 'WindDir3pm_S', 'WindDir3pm_ENE', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm', 'RainToday', 'Month']

# %%
len(modelo_mlauto.feature_name_)
# Out:
# 76

# %%
plot_model(modelo_mlauto, plot = 'feature')

# %% [markdown]
# Se observa que el modelo de MLauto obtuvo una leve mejora en las predicciones con respecto a los modelos anteriores, esta mejora se ve principalmente en la metrica Kappa score que mide la precisión del modelo mientras ajusta el rendimiento por la posibilidad de acertar por azar. Si el dataset está desbalanceado, un modelo podría parecer tener un buen rendimiento simplemente porque está prediciendo la clase dominante. El Kappa score ayuda a evaluar si el modelo realmente está mejorando en predecir entre clases de forma efectiva.
#
# Tambien se observa que el modelo de MLauto se volvio mucho mas complejo en comparación con los modelos anteriores ya que este modelo trabaja con 72 variables y los anteriores con 10. El modelo de MLauto cuenta con todas las variables numericas del dataset mas todas las dummies de las variables categoricas.
#
# Las 10 variables con mas impacto en el modelo de MLauto coinciden con las 10 variables que se eligieron despues del analisis SHAP con una unica diferencia en la variable 'Month' en MLauto y 'Pressure9am'.
